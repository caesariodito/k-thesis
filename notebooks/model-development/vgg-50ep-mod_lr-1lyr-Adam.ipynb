# %% [markdown]
# # Setup

# %%
from IPython.display import clear_output as cls

# %%
# data no split
# https://drive.google.com/file/d/1ey1O_1cZEnqP8s4mHjCvT8vpfAOlvP9L/view?usp=sharing

# data with split - train val test
# https://drive.google.com/file/d/14Rjq65k_qzXDje0atzyDl9WziapGaifp/view?usp=sharing

# data with split and converted - train val test
# https://drive.google.com/file/d/10eYtkh6bTWNwH_--xZtU8IxB5cZPVc3O/view?usp=drive_link

### ABOVE IS UNUSED

# data with split and converted clean - train val test
# https://drive.google.com/file/d/184s1XY7oZ2ukeMUzhMjH-MEXROGuGCk3/view?usp=drive_link

# data with split, converted clean, and augmented
# https://drive.google.com/file/d/1bydjm-fAYVwa-1J7J5riWVEWc2OVM3BZ/view?usp=drive_link

# !pip install gdown

# !rm -r dataset
# !gdown "https://drive.google.com/uc?id=184s1XY7oZ2ukeMUzhMjH-MEXROGuGCk3" -O dataset.zip
# !unzip dataset.zip -d dataset

cls()

# %%
# common
import os
import numpy as np
import tensorflow as tf
import typing
from tensorflow import keras
from typing import Tuple, List
from tqdm import tqdm
from glob import glob
from datetime import datetime

# preprocessing
from tensorflow import image as tfi

# architecture
from tensorflow.keras import Sequential
from tensorflow.keras.applications import Xception, InceptionV3, VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense

# visualization
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.utils import plot_model

# Model Training
# from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report

# CSV Callback
from tensorflow.keras.callbacks import CSVLogger

cls()

# %%
train_dir = '/kaggle/working/dataset/clean_data_splitted_convert/train/'
val_dir = '/kaggle/working/dataset/clean_data_splitted_convert/val/'
test_dir = '/kaggle/working/dataset/clean_data_splitted_convert/test/'

# %%
# Constants

IMAGE_SIZE = 300
BATCH_SIZE = 32
EPOCHS = 50
# EPOCHS = 1


LEARNING_RATE = 1e-4
# LEARNING_RATE = 1e-3


LOSS = tf.keras.losses.SparseCategoricalCrossentropy()
METRICS = ['accuracy']
# OPTIMIZER = Adam(learning_rate=LEARNING_RATE)
# OPTIMIZER = SGD(learning_rate=LEARNING_RATE)

# callback
EARLYSTOP_PATIENCE = 5


# Random Seed
random_seed = 42 # set random seed for reproducibility
tf.random.set_seed(random_seed) # set random seed for TensorFlow
np.random.seed(random_seed) # set random seed for NumPy

# %%
# Collect the class names
class_names = sorted(os.listdir(train_dir))
n_classes = len(class_names)

# %% [markdown]
# # Functions

# %%
def load_image(image_path: str) -> tf.Tensor:
    
    '''
    The task of the function is to load the image present in the specified given image path. Loading the image the function also performed some 
    preprocessing steps such as resizing and normalization.
    
    Argument:
        image_path(str) : This is a string which represents the location of the image file to be loaded.
        
    Returns:
        image(tf.Tensor) : This is the image which is loaded from the given image part in the form of a tensor.
    '''
    
    # Check if image path exists
    assert os.path.exists(image_path), f'Invalid image path: {image_path}'
    
    # Read the image file
    image = tf.io.read_file(image_path)
    
    # Load the image
    try:
        image = tfi.decode_jpeg(image, channels=3)
    except:
        image = tfi.decode_png(image, channels=3)
    
    # Change the image data type
    image = tfi.convert_image_dtype(image, tf.float32)
    
    # Resize the Image
    image = tfi.resize(image, (IMAGE_SIZE, IMAGE_SIZE))
    
    # Rescale pixel values to be in the range [0, 1]
    image = tf.image.per_image_standardization(image)
    
    # Convert image data type to tf.float32
    image = tf.cast(image, tf.float32)
    
    return image

# %%
def load_dataset(root_path: str, class_names: list, batch_size: int = 32, buffer_size: int = 1000) -> Tuple[np.ndarray, np.ndarray]:
    '''
    Load and preprocess images from the given root path and return them as numpy arrays.

    Args:
        root_path (str): Path to the root directory where all the subdirectories (class names) are present.
        class_names (list): List of the names of all the subdirectories (class names).
        batch_size (int): Batch size of the final dataset. Defaults to 32.
        buffer_size (int): Buffer size to use when shuffling the data. Defaults to 1000.

    Returns:
        Two numpy arrays, one containing the images and the other containing their respective labels.
    '''

    # Collect total number of data samples
    n_samples = sum([len(os.listdir(os.path.join(root_path, name))) for name in class_names])

    # Create arrays to store images and labels
    images = np.empty(shape=(n_samples, IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
    labels = np.empty(shape=(n_samples, 1), dtype=np.int32)

    errors = []
    
    # Loop over all the image file paths, load and store the images with respective labels
    n_image = 0
    for class_name in tqdm(class_names, desc="Loading"):
        class_path = os.path.join(root_path, class_name)
        for file_path in glob(os.path.join(class_path, "*")):
            # Load the image
            try:
                image = load_image(file_path)
                
                # Assign label
                label = class_names.index(class_name)

                # Store the image and the respective label
                images[n_image] = image
                labels[n_image] = label

                # Increment the number of images processed
                n_image += 1
                
            except:
                errors.append(file_path)
            
    # Shuffle the data
    indices = np.random.permutation(n_samples)
    images = images[indices]
    labels = labels[indices]
    
    print('num of errors:', len(errors))

    return images, labels, errors

# %%
def load_and_preprocess_image(image, label):
    # Resize the image to the desired size
    image = tf.image.resize(image, [IMAGE_SIZE, IMAGE_SIZE])
    
    # Rescale pixel values to be in the range [0, 1]
    image = tf.image.per_image_standardization(image)
    
#     # Convert image data type to tf.float32
#     image = tf.cast(image, tf.float32)
    
    return image, label

# %%
def plot_images(dataset: tf.data.Dataset, n_rows: int = 5, n_cols: int = 4, class_names=class_names, figsize=(20, 20), model=None, check=False):
    """
    Plots a grid of images and their corresponding labels from a tf.data.Dataset object.

    Args:
        dataset (tf.data.Dataset): A TensorFlow dataset object containing the images and labels to plot.
        n_rows (int): Number of rows in the plot grid. Default is 5.
        n_cols (int): Number of columns in the plot grid. Default is 4.
        class_names (list): A list of strings mapping the integer labels to their corresponding class names. Default is None.
        figsize (tuple): A tuple specifying the size of the figure. Default is (20, 20).
        model (tf.keras.Model): A trained TensorFlow model to make predictions on the images. Default is None.
        check (bool): If True and a model is provided, only incorrectly predicted images will be plotted. Default is False.
    """
    
    # Create a figure to display the images
    fig = plt.figure(figsize=figsize)
    
    # Initialize image counter
    image_count = 0
    
    # Loop over all batches in dataset
    for images, labels in dataset:
        
        # Loop over all images in batch
        for i in range(images.shape[0]):
            
            label = int(labels[i].numpy())
            title = "true: "+class_names[label]

            if model:
                pred = model.predict(images[i][np.newaxis])

                if check:
                    if label == np.argmax(pred):
                        continue

                pred_label = f"Pred: {np.argmax(pred)}"
                pred_percentage = f" ({np.max(pred) * 100:.2f}%)"
                if class_names:
                    pred_label += f" ({class_names[np.argmax(pred)]})"
                title += f"\n{pred_label} {pred_percentage}"

            # Create a subplot for each image
            ax = fig.add_subplot(n_rows, n_cols, image_count+1)    

            # Plot the image
            ax.imshow(images[i].numpy().astype("uint8"))

            # Set the title to the corresponding label
            ax.set_title(title)

            # Remove the axis ticks
            ax.set_xticks([])
            ax.set_yticks([])
            
            # Increment image counter
            image_count += 1
            
            # Check if maximum number of images has been reached
            if image_count >= n_rows * n_cols:
                break
        
        # Check if maximum number of images has been reached
        if image_count >= n_rows * n_cols:
            break
    
    # Show the plot
    plt.show()

# %%
def timer(start_time: datetime = None) -> "typing.Union[datetime.datetime, str]":
    """
    Measures the time elapsed from a given start time.

    If no start time is provided, returns the current time. If a start time is provided, returns a formatted string
    representing the time elapsed from the start time to the current time.

    Args:
        start_time (datetime.datetime, optional): The start time to measure elapsed time from, or None to get the current time. Defaults to None.

    Returns:
        Union[datetime.datetime, str]: The current time if no start time is provided, or a formatted string representing the elapsed time.
    """
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        return "%i hours %i minutes and %s seconds." % (
            thour,
            tmin,
            round(tsec, 2),
        )

# %%
def plot_history(history, test_loss, test_acc, model_name):
    # Collect the history of the training run
    history_plot = pd.DataFrame(history.history)
    
    # Create a figure to display the model's performance
    plt.figure(figsize=(20, 5))

    # Plot the loss curve in the first subplot
    plt.subplot(1, 2, 1)
    plt.title(f"{model_name} - Loss Curve")
    plt.plot(history_plot['loss'], label="Training Loss")
    plt.plot(history_plot['val_loss'], label="Validation Loss")

    # Horizontal line to show the testing performance
    plt.axhline(y=test_loss, label="Test Loss", linestyle='--', color='green')

    # Set the x- and y-labels, and the x- and y-limits
    plt.xlabel("Epochs")
    plt.ylabel("Cross Entropy Loss")
    # plt.ylim([0, 0.4])

    # Show the legend and grid
    plt.legend()
    plt.grid()

    # Plot the accuracy curve in the second subplot
    plt.subplot(1, 2, 2)
    plt.title(f"{model_name} - Accuracy Curve")
    plt.plot(history_plot['accuracy'], label="Training Accuracy")
    plt.plot(history_plot['val_accuracy'], label="Validation Accuracy")

    # Horizontal line to show the testing performance
    plt.axhline(y=test_acc, label="Test Accuracy", linestyle='--', color='green')

    # Set the x- and y-labels, and the x- and y-limits
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    # plt.ylim([0.85, 1])

    # Show the legend and grid
    plt.legend()
    plt.grid()

    # Display the plot
    plt.show()

# %%
def plot_confusion_m(y_true, y_pred, class_names=None, figsize=(15,15)):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %% [markdown]
# # Data Prep

# %%
# Show
print(f"Total number of classes in train: {n_classes}")
print(f"Classes: {class_names}")
# Out:
# Total number of classes in train: 20
# Classes: ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# %%
# # Load the training dataset
# X_train, y_train, err_train = load_dataset(root_path = train_dir, class_names = class_names)

# # # Load the validation dataset
# X_valid, y_valid, err_val = load_dataset(root_path = val_dir, class_names = class_names)

# # Load the testing dataset
# X_test, y_test, err_test = load_dataset(root_path = test_dir, class_names = class_names)

# %%
# print('train err:', err_train)
# print('val err:', err_val)
# print('test err:', err_test)

# %%
# del X_train, y_train, X_valid, y_valid, X_test, y_test

# %% [markdown]
# ## Drop corrupted data

# %%
corrupted = '/kaggle/working/dataset/clean_data_splitted_convert/train/ra/000021.jpg'
os.remove(corrupted)

# %% [markdown]
# # Create Dataset

# %%
# del train_ds, val_ds, test_ds
# del train_ds_mapped, val_ds_mapped, test_ds_mapped

# Create a dataset from the data directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(train_dir, 
#                                                                labels='inferred', 
#                                                                label_mode='int',
#                                                                image_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                               batch_size=BATCH_SIZE
                                                              )

val_ds = tf.keras.preprocessing.image_dataset_from_directory(val_dir,
#                                                              labels='inferred', 
#                                                              label_mode='int',
#                                                              image_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                             batch_size=BATCH_SIZE
                                                              )

test_ds = tf.keras.preprocessing.image_dataset_from_directory(test_dir, 
#                                                                labels='inferred', 
#                                                                label_mode='int',
#                                                                image_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                               batch_size=BATCH_SIZE
                                                              )
# Out:
# Found 3404 files belonging to 20 classes.
# Found 207 files belonging to 20 classes.
# Found 202 files belonging to 20 classes.

# %% [markdown]
# ## Preprocessing

# %%
train_ds_mapped = train_ds.map(load_and_preprocess_image)
val_ds_mapped = val_ds.map(load_and_preprocess_image)
test_ds_mapped = test_ds.map(load_and_preprocess_image)

train_ds_mapped.prefetch(tf.data.AUTOTUNE)
val_ds_mapped.prefetch(tf.data.AUTOTUNE)
test_ds_mapped.prefetch(tf.data.AUTOTUNE)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Data Visualization

# %%
# Calculate class distribution
class_dis = [len(os.listdir(train_dir + name)) for name in class_names]
# class_dis = [len(os.listdir(val_dir + name)) for name in class_names]
# class_dis = [len(os.listdir(test_dir + name)) for name in class_names]

# Visualize using interactive pie chart
pie_chart = px.pie(values=class_dis, names=class_names, color=class_names)
pie_chart.update_layout({'title':{'text':"Class Distribution"}})
pie_chart.show()

# Visualize using interactive bar chart
bar_chart = px.bar(y=class_dis, x=class_names, color=class_names)
bar_chart.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="baadb9c6-04ee-4b8e-81a2-ecb273377e0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("baadb9c6-04ee-4b8e-81a2-ecb273377e0f")) {                    Plotly.newPlot(                        "baadb9c6-04ee-4b8e-81a2-ecb273377e0f",                        [{"customdata":[["ba"],["ca"],["da"],["dha"],["ga"],["ha"],["ja"],["ka"],["la"],["ma"],["na"],["nga"],["nya"],["pa"],["ra"],["sa"],["ta"],["tha"],["wa"],["ya"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["ba","ca","da","dha","ga","ha","ja","ka","la","ma","na","nga","nya","pa","ra","sa","ta","tha","wa","ya"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"","showlegend":true,"values":[172,182,167,144,159,164,176,162,169,172,176,178,169,187,157,185,155,180,162,188],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...
# <div>                            <div id="859f3433-cccc-438c-9b2f-73da55e215d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("859f3433-cccc-438c-9b2f-73da55e215d4")) {                    Plotly.newPlot(                        "859f3433-cccc-438c-9b2f-73da55e215d4",                        [{"alignmentgroup":"True","hovertemplate":"color=ba<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ba","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ba","offsetgroup":"ba","orientation":"v","showlegend":true,"textposition":"auto","x":["ba"],"xaxis":"x","y":[172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ca<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ca","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ca","offsetgroup":"ca","orientation":"v","showlegend":true,"textposition":"auto","x":["ca"],"xaxis":"x","y":[182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=da<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"da","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"da","offsetgroup":"da","orientation":"v","showlegend":true,"textposition":"auto","x":["da"],"xaxis":"x","y":[167],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=dha<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"dha","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dha","offsetgroup":"dha","orientation":"v","showlegend":true,"textposition":"auto","x":["dha"],"xaxis":"x","y":[144],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ga<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ga","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ga","offsetgroup":"ga","orientation":"v","showlegend":true,"textposition":"auto","x":["ga"],"xaxis":"x","y":[159],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ha<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ha","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ha","offsetgroup":"ha","orientation":"v","showlegend":true,"textposition":"auto","x":["ha"],"xaxis":"x","y":[164],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ja<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ja","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"ja","offsetgroup":"ja","orientation":"v","showlegend":true,"textposition":"auto","x":["ja"],"xaxis":"x","y":[176],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ka<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ka","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"ka","offsetgroup":"ka","orientation":"v","showlegend":true,"textposition":"auto","x":["ka"],"xaxis":"x","y":[162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=la<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"la","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"la","offsetgroup":"la","orientation":"v","showlegend":true,"textposition":"auto","x":["la"],"xaxis":"x","y":[169],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ma<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ma","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"ma","offsetgroup":"ma","orientation":"v","showlegend":true,"textposition":"auto","x":["ma"],"xaxis":"x","y":[172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=na<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"na","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"na","offsetgroup":"na","orientation":"v","showlegend":true,"textposition":"auto","x":["na"],"xaxis":"x","y":[176],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=nga<br>x=%{x}<br>y=%{y}<extra></extra>","legendgro ...

# %%
plot_images(train_ds)

# %%
plot_images(train_ds_mapped)

# %% [markdown]
# # Model Building

# %%
# Download vgg

vgg_no_train = VGG16(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)
vgg_no_train.trainable = False

vgg_half_train = VGG16(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)
vgg_half_train.trainable = True

vgg_full_train = VGG16(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)
vgg_full_train.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
# half freeze
num_layers = len(vgg_half_train.layers) // 2
num_layers
for i in range(num_layers):
    vgg_half_train.layers[i].trainable = False

# %% [markdown]
# # Model Summary

# %%
# full freeze
name = 'aksara_jawa_vgg_full_freeze_v1'

vgg_transferred_full = Sequential([
    vgg_no_train,
    GlobalAveragePooling2D(),
    
    # 1 layer
    Dropout(0.5),
    
#     Dense(1024, activation='relu'),
#     # 2 layer
#     Dropout(0.25),
    
    Dense(n_classes, activation='softmax')
], name=name)

vgg_transferred_full.compile(
    loss=LOSS,
#     optimizer=SGD(learning_rate=LEARNING_RATE),
    optimizer=Adam(learning_rate=LEARNING_RATE),
    metrics=METRICS
)

vgg_transferred_full.summary()
print('\n\n\n', '*'*90)


# half
name = 'aksara_jawa_vgg_half_freeze_v1'

vgg_transferred_half = Sequential([
    vgg_half_train,
    GlobalAveragePooling2D(),
    
    # 1 layer
    Dropout(0.5),
    
#     Dense(1024, activation='relu'),    
#     # 2 layer
#     Dropout(0.25),
    
    Dense(n_classes, activation='softmax')
], name=name)

vgg_transferred_half.compile(
    loss=LOSS,
#     optimizer=SGD(learning_rate=LEARNING_RATE),
    optimizer=Adam(learning_rate=LEARNING_RATE),
    metrics=METRICS
)

vgg_transferred_half.summary()
print('\n\n\n', '*'*90)


# no freeze
name = 'aksara_jawa_vgg_no_freeze_v1'

vgg_transferred_no = Sequential([
    vgg_full_train,
    GlobalAveragePooling2D(),
    
    # 1 layer
    Dropout(0.5),
    
#     Dense(1024, activation='relu'),
#     # 2 layer
#     Dropout(0.25),
    
    Dense(n_classes, activation='softmax')
], name=name)

vgg_transferred_no.compile(
    loss=LOSS,
#     optimizer=SGD(learning_rate=LEARNING_RATE),
    optimizer=Adam(learning_rate=LEARNING_RATE),
    metrics=METRICS
)

vgg_transferred_no.summary()
# Out:
# Model: "aksara_jawa_vgg_full_freeze_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 20)                10260
#
# =================================================================
# Total params: 14,724,948
# Trainable params: 10,260
# Non-trainable params: 14,714,688
# _________________________________________________________________
#
#
#
#  ******************************************************************************************
# Model: "aksara_jawa_vgg_half_freeze_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 14,724,948
# Trainable params: 13,579,540
# Non-trainable params: 1,145,408
# _________________________________________________________________
#
#
#
#  ******************************************************************************************
# Model: "aksara_jawa_vgg_no_freeze_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 14,724,948
# Trainable params: 14,724,948
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train Full Freeze

# %%
print(f"\nTraining {vgg_transferred_full.name}: ")

csv_file = f'{vgg_transferred_full.name}.csv'

time = timer(None)
history_full = vgg_transferred_full.fit(
    train_ds_mapped, 
    validation_data=val_ds_mapped, 
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=EARLYSTOP_PATIENCE, restore_best_weights=True),
        ModelCheckpoint(f"checkpoint-{vgg_transferred_full.name}.h5", save_best_only=True),
        CSVLogger(csv_file)
    ],
    batch_size=BATCH_SIZE,
)
time_taken = timer(time)
print(time_taken)
# Out:
# Training aksara_jawa_vgg_full_freeze_v1:
# Epoch 1/50
# 107/107 [==============================] - 32s 200ms/step - loss: 3.3413 - accuracy: 0.0470 - val_loss: 3.0838 - val_accuracy: 0.0676
# Epoch 2/50
# 107/107 [==============================] - 16s 147ms/step - loss: 3.2135 - accuracy: 0.0523 - val_loss: 3.0142 - val_accuracy: 0.0870
# Epoch 3/50
# 107/107 [==============================] - 15s 141ms/step - loss: 3.1427 - accuracy: 0.0520 - val_loss: 2.9811 - val_accuracy: 0.0966
# Epoch 4/50
# 107/107 [==============================] - 16s 146ms/step - loss: 3.0919 - accuracy: 0.0570 - val_loss: 2.9609 - val_accuracy: 0.1208
# Epoch 5/50
# 107/107 [==============================] - 16s 143ms/step - loss: 3.0690 - accuracy: 0.0573 - val_loss: 2.9443 - val_accuracy: 0.1304
# Epoch 6/50
# 107/107 [==============================] - 16s 143ms/step - loss: 3.0415 - accuracy: 0.0655 - val_loss: 2.9291 - val_accuracy: 0.1546
# Epoch 7/50
# 107/107 [==============================] - 16s 147ms/step - loss: 3.0273 - accuracy: 0.0720 - val_loss: 2.9137 - val_accuracy: 0.1787
# Epoch 8/50
# 107/107 [==============================] - 16s 144ms/step - loss: 3.0097 - accuracy: 0.0752 - val_loss: 2.8987 - val_accuracy: 0.2077
# Epoch 9/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.9866 - accuracy: 0.0787 - val_loss: 2.8836 - val_accuracy: 0.2174
# Epoch 10/50
# 107/107 [==============================] - 16s 144ms/step - loss: 2.9486 - accuracy: 0.0928 - val_loss: 2.8683 - val_accuracy: 0.2271
# Epoch 11/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.9492 - accuracy: 0.0902 - val_loss: 2.8531 - val_accuracy: 0.2464
# Epoch 12/50
# 107/107 [==============================] - 16s 143ms/step - loss: 2.9293 - accuracy: 0.0967 - val_loss: 2.8387 - val_accuracy: 0.2899
# Epoch 13/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.8936 - accuracy: 0.1290 - val_loss: 2.8242 - val_accuracy: 0.3092
# Epoch 14/50
# 107/107 [==============================] - 16s 142ms/step - loss: 2.8725 - accuracy: 0.1243 - val_loss: 2.8097 - val_accuracy: 0.3382
# Epoch 15/50
# 107/107 [==============================] - 16s 143ms/step - loss: 2.8667 - accuracy: 0.1281 - val_loss: 2.7955 - val_accuracy: 0.3671
# Epoch 16/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.8509 - accuracy: 0.1401 - val_loss: 2.7817 - val_accuracy: 0.3816
# Epoch 17/50
# 107/107 [==============================] - 16s 142ms/step - loss: 2.8329 - accuracy: 0.1484 - val_loss: 2.7677 - val_accuracy: 0.4058
# Epoch 18/50
# 107/107 [==============================] - 16s 149ms/step - loss: 2.8243 - accuracy: 0.1481 - val_loss: 2.7541 - val_accuracy: 0.4203
# Epoch 19/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.8077 - accuracy: 0.1560 - val_loss: 2.7403 - val_accuracy: 0.4300
# Epoch 20/50
# 107/107 [==============================] - 16s 145ms/step - loss: 2.7902 - accuracy: 0.1730 - val_loss: 2.7270 - val_accuracy: 0.4444
# Epoch 21/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.7870 - accuracy: 0.1792 - val_loss: 2.7140 - val_accuracy: 0.4638
# Epoch 22/50
# 107/107 [==============================] - 16s 142ms/step - loss: 2.7708 - accuracy: 0.1842 - val_loss: 2.7009 - val_accuracy: 0.4831
# Epoch 23/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.7471 - accuracy: 0.1989 - val_loss: 2.6883 - val_accuracy: 0.5024
# Epoch 24/50
# 107/107 [==============================] - 16s 145ms/step - loss: 2.7300 - accuracy: 0.2156 - val_loss: 2.6753 - val_accuracy: 0.4783
# Epoch 25/50
# 107/107 [==============================] - 17s 150ms/step - loss: 2.7172 - accuracy: 0.2174 - val_loss: 2.6625 - val_accuracy: 0.4928
# Epoch 26/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.7182 - accuracy: 0.2133 - val_loss: 2.6503 - val_accuracy: 0.5217
# Epoch 27/50
# 107/107 [==============================] - 17s 150ms/step - loss: 2.7035 - accuracy: 0.2218 - val_loss: 2.6380 - val_accuracy: 0.5169
# Epoch 28/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.6794 - accuracy: 0.2497 - val_loss: 2.6257 - val_accuracy: 0.5411
# Epoch 29/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.6689 - accuracy: 0.2415 - val_loss: 2.6136 - val_accuracy: 0.5459
# Epoch 30/50
# 107/107 [==============================] - 16s 150ms/step - loss: 2.6532 - accuracy: 0.2600 - val_loss: 2.6018 - val_accuracy: 0.5604
# Epoch 31/50
# 107/107 [==============================] - 16s 143ms/step - loss: 2.6488 - accuracy: 0.2609 - val_loss: 2.5900 - val_accuracy: 0.5556
# Epoch 32/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.6337 - accuracy: 0.2712 - val_loss: 2.5783 - val_accuracy: 0.5749
# Epoch 33/50
# 107/107 [==============================] - 16s 143ms/step - loss: 2.6190 - accuracy: 0.2811 - val_loss: 2.5665 - val_accuracy: 0.5845
# Epoch 34/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.6207 - accuracy: 0.2726 - val_loss: 2.5550 - val_accuracy: 0.5942
# Epoch 35/50
# 107/107 [==============================] - 16s 145ms/step - loss: 2.5994 - accuracy: 0.2985 - val_loss: 2.5435 - val_accuracy: 0.6135
# Epoch 36/50
# 107/107 [==============================] - 16s 142ms/step - loss: 2.5848 - accuracy: 0.2905 - val_loss: 2.5324 - val_accuracy: 0.6039
# Epoch 37/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.5833 - accuracy: 0.2982 - val_loss: 2.5212 - val_accuracy: 0.6280
# Epoch 38/50
# 107/107 [==============================] - 17s 157ms/step - loss: 2.5723 - accuracy: 0.3102 - val_loss: 2.5103 - val_accuracy: 0.6425
# Epoch 39/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.5602 - accuracy: 0.3085 - val_loss: 2.4993 - val_accuracy: 0.6425
# Epoch 40/50
# 107/107 [==============================] - 16s 145ms/step - loss: 2.5551 - accuracy: 0.3164 - val_loss: 2.4887 - val_accuracy: 0.6522
# Epoch 41/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.5378 - accuracy: 0.3273 - val_loss: 2.4782 - val_accuracy: 0.6570
# Epoch 42/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.5244 - accuracy: 0.3443 - val_loss: 2.4674 - val_accuracy: 0.6522
# Epoch 43/50
# 107/107 [==============================] - 16s 149ms/step - loss: 2.5133 - accuracy: 0.3455 - val_loss: 2.4568 - val_accuracy: 0.6667
# Epoch 44/50
# 107/107 [==============================] - 16s 144ms/step - loss: 2.5082 - accuracy: 0.3519 - val_loss: 2.4466 - val_accuracy: 0.6763
# Epoch 45/50
# 107/107 [==============================] - 16s 148ms/step - loss: 2.5047 - accuracy: 0.3422 - val_loss: 2.4366 - val_accuracy: 0.6812
# Epoch 46/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.4905 - accuracy: 0.3610 - val_loss: 2.4261 - val_accuracy: 0.6860
# Epoch 47/50
# 107/107 [==============================] - 16s 145ms/step - loss: 2.4820 - accuracy: 0.3578 - val_loss: 2.4160 - val_accuracy: 0.6957
# Epoch 48/50
# 107/107 [==============================] - 16s 150ms/step - loss: 2.4823 - accuracy: 0.3605 - val_loss: 2.4063 - val_accuracy: 0.6860
# Epoch 49/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.4547 - accuracy: 0.3831 - val_loss: 2.3963 - val_accuracy: 0.7005
# Epoch 50/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.4548 - accuracy: 0.3807 - val_loss: 2.3865 - val_accuracy: 0.7053
# 0 hours 15 minutes and 39.12 seconds.

# %% [markdown]
# # Train Half Freeze

# %%
print(f"\nTraining {vgg_transferred_half.name}: ")

csv_file = f'{vgg_transferred_half.name}.csv'

time = timer(None)
history_half = vgg_transferred_half.fit(
    train_ds_mapped, 
    validation_data=val_ds_mapped, 
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=EARLYSTOP_PATIENCE, restore_best_weights=True),
        ModelCheckpoint(f"checkpoint-{vgg_transferred_half.name}.h5", save_best_only=True),
        CSVLogger(csv_file)
    ],
    batch_size=BATCH_SIZE,
)
time_taken = timer(time)
print(time_taken)
# Out:
# Training aksara_jawa_vgg_half_freeze_v1:
# Epoch 1/50
# 107/107 [==============================] - 32s 238ms/step - loss: 2.6107 - accuracy: 0.1724 - val_loss: 1.6673 - val_accuracy: 0.4444
# Epoch 2/50
# 107/107 [==============================] - 25s 229ms/step - loss: 1.3018 - accuracy: 0.5790 - val_loss: 0.3875 - val_accuracy: 0.9179
# Epoch 3/50
# 107/107 [==============================] - 25s 228ms/step - loss: 0.4575 - accuracy: 0.8458 - val_loss: 0.1226 - val_accuracy: 0.9662
# Epoch 4/50
# 107/107 [==============================] - 25s 229ms/step - loss: 0.2351 - accuracy: 0.9307 - val_loss: 0.0860 - val_accuracy: 0.9758
# Epoch 5/50
# 107/107 [==============================] - 24s 222ms/step - loss: 0.1165 - accuracy: 0.9647 - val_loss: 0.1030 - val_accuracy: 0.9807
# Epoch 6/50
# 107/107 [==============================] - 26s 242ms/step - loss: 0.0974 - accuracy: 0.9727 - val_loss: 0.0454 - val_accuracy: 0.9807
# Epoch 7/50
# 107/107 [==============================] - 25s 230ms/step - loss: 0.0485 - accuracy: 0.9853 - val_loss: 0.0161 - val_accuracy: 0.9952
# Epoch 8/50
# 107/107 [==============================] - 24s 225ms/step - loss: 0.0393 - accuracy: 0.9903 - val_loss: 0.0281 - val_accuracy: 0.9807
# Epoch 9/50
# 107/107 [==============================] - 25s 227ms/step - loss: 0.0506 - accuracy: 0.9874 - val_loss: 0.0107 - val_accuracy: 0.9952
# Epoch 10/50
# 107/107 [==============================] - 25s 230ms/step - loss: 0.0333 - accuracy: 0.9906 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 11/50
# 107/107 [==============================] - 24s 225ms/step - loss: 0.0270 - accuracy: 0.9915 - val_loss: 0.0055 - val_accuracy: 0.9952
# Epoch 12/50
# 107/107 [==============================] - 25s 226ms/step - loss: 0.0240 - accuracy: 0.9938 - val_loss: 0.0403 - val_accuracy: 0.9952
# Epoch 13/50
# 107/107 [==============================] - 24s 224ms/step - loss: 0.0329 - accuracy: 0.9909 - val_loss: 0.0049 - val_accuracy: 0.9952
# Epoch 14/50
# 107/107 [==============================] - 25s 226ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 0.0262 - val_accuracy: 0.9952
# Epoch 15/50
# 107/107 [==============================] - 25s 230ms/step - loss: 0.0207 - accuracy: 0.9944 - val_loss: 6.6962e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 107/107 [==============================] - 24s 224ms/step - loss: 0.0769 - accuracy: 0.9794 - val_loss: 0.1946 - val_accuracy: 0.9807
# Epoch 17/50
# 107/107 [==============================] - 24s 225ms/step - loss: 0.0469 - accuracy: 0.9894 - val_loss: 0.0359 - val_accuracy: 0.9952
# Epoch 18/50
# 107/107 [==============================] - 25s 226ms/step - loss: 0.0139 - accuracy: 0.9974 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 19/50
# 107/107 [==============================] - 25s 229ms/step - loss: 0.0143 - accuracy: 0.9971 - val_loss: 6.1095e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 107/107 [==============================] - 25s 226ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0165 - val_accuracy: 0.9952
# Epoch 21/50
# 107/107 [==============================] - 25s 224ms/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 0.0147 - val_accuracy: 0.9952
# Epoch 22/50
# 107/107 [==============================] - 25s 227ms/step - loss: 0.0184 - accuracy: 0.9959 - val_loss: 3.0273e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 107/107 [==============================] - 25s 226ms/step - loss: 0.0197 - accuracy: 0.9938 - val_loss: 4.4778e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 107/107 [==============================] - 24s 225ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0387 - val_accuracy: 0.9903
# Epoch 25/50
# 107/107 [==============================] - 24s 224ms/step - loss: 0.0205 - accuracy: 0.9938 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 26/50
# 107/107 [==============================] - 24s 224ms/step - loss: 0.0488 - accuracy: 0.9900 - val_loss: 0.3972 - val_accuracy: 0.9662
# Epoch 27/50
# 107/107 [==============================] - 25s 229ms/step - loss: 0.0548 - accuracy: 0.9868 - val_loss: 2.4996e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 107/107 [==============================] - 25s 225ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 5.0337e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 107/107 [==============================] - 25s 227ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0055 - val_accuracy: 0.9952
# Epoch 30/50
# 107/107 [==============================] - 26s 240ms/step - loss: 7.6698e-04 - accuracy: 1.0000 - val_loss: 1.7737e-05 - val_accuracy: 1.0000
# Epoch 31/50
# 107/107 [==============================] - 25s 224ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0318 - val_accuracy: 0.9903
# Epoch 32/50
# 107/107 [==============================] - 25s 226ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 5.1174e-05 - val_accuracy: 1.0000
# Epoch 33/50
# 107/107 [==============================] - 24s 225ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 34/50
# 107/107 [==============================] - 24s 223ms/step - loss: 0.0255 - accuracy: 0.9947 - val_loss: 0.0210 - val_accuracy: 0.9952
# Epoch 35/50
# 107/107 [==============================] - 25s 225ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 2.0527e-04 - val_accuracy: 1.0000
# 0 hours 18 minutes and 0.96 seconds.

# %% [markdown]
# # Train No Freeze

# %%
print(f"\nTraining {vgg_transferred_no.name}: ")

csv_file = f'{vgg_transferred_no.name}.csv'

time = timer(None)
history_no = vgg_transferred_no.fit(
    train_ds_mapped, 
    validation_data=val_ds_mapped, 
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=EARLYSTOP_PATIENCE, restore_best_weights=True),
        ModelCheckpoint(f"checkpoint-{vgg_transferred_no.name}.h5", save_best_only=True),
        CSVLogger(csv_file)
    ],
    batch_size=BATCH_SIZE,
)
time_taken = timer(time)
print(time_taken)
# Out:
# Training aksara_jawa_vgg_no_freeze_v1:
# Epoch 1/50
# 107/107 [==============================] - 66s 406ms/step - loss: 3.0198 - accuracy: 0.0429 - val_loss: 2.9957 - val_accuracy: 0.0483
# Epoch 2/50
# 107/107 [==============================] - 42s 392ms/step - loss: 2.9960 - accuracy: 0.0576 - val_loss: 2.9956 - val_accuracy: 0.0483
# Epoch 3/50
# 107/107 [==============================] - 42s 388ms/step - loss: 2.9956 - accuracy: 0.0552 - val_loss: 2.9956 - val_accuracy: 0.0531
# Epoch 4/50
# 107/107 [==============================] - 42s 390ms/step - loss: 2.9956 - accuracy: 0.0532 - val_loss: 2.9956 - val_accuracy: 0.0531
# Epoch 5/50
# 107/107 [==============================] - 43s 392ms/step - loss: 2.9955 - accuracy: 0.0532 - val_loss: 2.9955 - val_accuracy: 0.0531
# Epoch 6/50
# 107/107 [==============================] - 42s 390ms/step - loss: 2.9955 - accuracy: 0.0543 - val_loss: 2.9955 - val_accuracy: 0.0531
# Epoch 7/50
# 107/107 [==============================] - 42s 391ms/step - loss: 2.9954 - accuracy: 0.0523 - val_loss: 2.9955 - val_accuracy: 0.0531
# Epoch 8/50
# 107/107 [==============================] - 44s 406ms/step - loss: 2.9954 - accuracy: 0.0541 - val_loss: 2.9954 - val_accuracy: 0.0531
# Epoch 9/50
# 107/107 [==============================] - 42s 393ms/step - loss: 2.9953 - accuracy: 0.0464 - val_loss: 2.9954 - val_accuracy: 0.0531
# Epoch 10/50
# 107/107 [==============================] - 43s 392ms/step - loss: 2.9951 - accuracy: 0.0555 - val_loss: 2.9954 - val_accuracy: 0.0531
# Epoch 11/50
# 107/107 [==============================] - 42s 393ms/step - loss: 2.9952 - accuracy: 0.0541 - val_loss: 2.9953 - val_accuracy: 0.0531
# Epoch 12/50
# 107/107 [==============================] - 42s 391ms/step - loss: 2.9952 - accuracy: 0.0543 - val_loss: 2.9951 - val_accuracy: 0.0676
# Epoch 13/50
# 107/107 [==============================] - 42s 387ms/step - loss: 2.9951 - accuracy: 0.0561 - val_loss: 2.9953 - val_accuracy: 0.0531
# Epoch 14/50
# 107/107 [==============================] - 42s 389ms/step - loss: 2.9951 - accuracy: 0.0552 - val_loss: 2.9953 - val_accuracy: 0.0531
# Epoch 15/50
# 107/107 [==============================] - 42s 388ms/step - loss: 2.9950 - accuracy: 0.0552 - val_loss: 2.9952 - val_accuracy: 0.0531
# Epoch 16/50
# 107/107 [==============================] - 42s 388ms/step - loss: 2.9950 - accuracy: 0.0552 - val_loss: 2.9952 - val_accuracy: 0.0531
# Epoch 17/50
# 107/107 [==============================] - 42s 388ms/step - loss: 2.9949 - accuracy: 0.0552 - val_loss: 2.9952 - val_accuracy: 0.0531
# 0 hours 14 minutes and 12.83 seconds.

# %% [markdown]
# # Evaluate

# %%
print('\nfull freeze')
test_loss_f, test_acc_f = vgg_transferred_full.evaluate(test_ds_mapped)
print("Loss    : {:.4}".format(test_loss_f))
print("Accuracy: {:.4}%".format(test_acc_f*100))

print('\nhalf freeze')
test_loss_h, test_acc_h = vgg_transferred_half.evaluate(test_ds_mapped)
print("Loss    : {:.4}".format(test_loss_h))
print("Accuracy: {:.4}%".format(test_acc_h*100))

print('\nno freeze')
test_loss_n, test_acc_n = vgg_transferred_no.evaluate(test_ds_mapped)
print("Loss    : {:.4}".format(test_loss_n))
print("Accuracy: {:.4}%".format(test_acc_n*100))
# Out:
# full freeze
# 7/7 [==============================] - 2s 308ms/step - loss: 2.3941 - accuracy: 0.6436
# Loss    : 2.394
# Accuracy: 64.36%
#
# half freeze
# 7/7 [==============================] - 1s 116ms/step - loss: 0.0152 - accuracy: 0.9950
# Loss    : 0.01521
# Accuracy: 99.5%
#
# no freeze
# 7/7 [==============================] - 1s 113ms/step - loss: 2.9951 - accuracy: 0.0545
# Loss    : 2.995
# Accuracy: 5.446%

# %% [markdown]
# # Graph

# %%
plot_history(history_full, test_loss_f, test_acc_f, 'vgg Full')
plot_history(history_half, test_loss_h, test_acc_h, 'vgg Half')
plot_history(history_no, test_loss_n, test_acc_n, 'vgg No')

# %% [markdown]
# # Confusion Matrix

# %%
y_f, y_h, y_n, = [], [], []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for image_batch, label_batch in test_ds_mapped:   # use dataset.unbatch() with repeat
    # append true labels
    y_true.append(label_batch)
    # compute predictions
    preds_f = vgg_transferred_full.predict(image_batch, verbose=0)
    preds_h = vgg_transferred_half.predict(image_batch, verbose=0)
    preds_n = vgg_transferred_no.predict(image_batch, verbose=0)
    # append predicted labels
    y_f.append(np.argmax(preds_f, axis = - 1))
    y_h.append(np.argmax(preds_h, axis = - 1))
    y_n.append(np.argmax(preds_n, axis = - 1))

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels_f = tf.concat([item for item in y_f], axis = 0)
predicted_labels_h = tf.concat([item for item in y_h], axis = 0)
predicted_labels_n = tf.concat([item for item in y_n], axis = 0)

cls()

# %%
print('\nfull freeze')
plot_confusion_m(correct_labels, predicted_labels_f, class_names)

print('\nhalf freeze')
plot_confusion_m(correct_labels, predicted_labels_h, class_names)

print('\nno freeze')
plot_confusion_m(correct_labels, predicted_labels_n, class_names)
# Out:
# full freeze
# half freeze
# no freeze

# %% [markdown]
# # Prediction Visualization

# %%
plot_images(test_ds_mapped, model=vgg_transferred_full, n_rows=5)
# Out:
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
plot_images(test_ds_mapped, model=vgg_transferred_half, n_rows=5)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
plot_images(test_ds_mapped, model=vgg_transferred_no, n_rows=5)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# # CSV Preview

# %%
pd.read_csv(f'{vgg_transferred_full.name}.csv').head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.047004  3.341283      0.067633  3.083817
# 1      1  0.052291  3.213501      0.086957  3.014194
# 2      2  0.051998  3.142722      0.096618  2.981056
# 3      3  0.056992  3.091929      0.120773  2.960875
# 4      4  0.057286  3.069007      0.130435  2.944261

# %%
pd.read_csv(f'{vgg_transferred_half.name}.csv').head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.172444  2.610706      0.444444  1.667316
# 1      1  0.579025  1.301782      0.917874  0.387538
# 2      2  0.845770  0.457538      0.966184  0.122578
# 3      3  0.930670  0.235103      0.975845  0.086022
# 4      4  0.964747  0.116519      0.980676  0.103008

# %%
pd.read_csv(f'{vgg_transferred_no.name}.csv').head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.042891  3.019817      0.048309  2.995650
# 1      1  0.057579  2.995991      0.048309  2.995581
# 2      2  0.055229  2.995648      0.053140  2.995612
# 3      3  0.053173  2.995570      0.053140  2.995573
# 4      4  0.053173  2.995520      0.053140  2.995537

# %% [markdown]
# # Save Model

# %%
vgg_transferred_full.save(vgg_transferred_full.name+'.h5')
vgg_transferred_half.save(vgg_transferred_half.name+'.h5')
vgg_transferred_no.save(vgg_transferred_no.name+'.h5')
