# %%
from IPython.display import clear_output as cls

# %%
# data no split
# https://drive.google.com/file/d/1ey1O_1cZEnqP8s4mHjCvT8vpfAOlvP9L/view?usp=sharing

# data with split - train val test
# https://drive.google.com/file/d/14Rjq65k_qzXDje0atzyDl9WziapGaifp/view?usp=sharing

# data with split and converted - train val test
# https://drive.google.com/file/d/10eYtkh6bTWNwH_--xZtU8IxB5cZPVc3O/view?usp=drive_link
    
# data with split and converted clean - train val test
# https://drive.google.com/file/d/184s1XY7oZ2ukeMUzhMjH-MEXROGuGCk3/view?usp=drive_link
# !pip install gdown

# !rm -r dataset
# !gdown "https://drive.google.com/uc?id=184s1XY7oZ2ukeMUzhMjH-MEXROGuGCk3" -O dataset.zip
# !unzip dataset.zip -d dataset

cls()

# %%
# common
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from typing import Tuple, List
from tqdm import tqdm
from glob import glob
from datetime import datetime

# preprocessing
from tensorflow import image as tfi

# architecture
from tensorflow.keras import Sequential
from tensorflow.keras.applications import Xception, InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense

# visualization
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# Model Training
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# output cell
from IPython.display import clear_output as cls
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
train_dir = '/kaggle/working/dataset/clean_data_splitted_convert/train/'
val_dir = '/kaggle/working/dataset/clean_data_splitted_convert/val/'
test_dir = '/kaggle/working/dataset/clean_data_splitted_convert/test/'

# %%
# Constants

IMAGE_SIZE = 300
BATCH_SIZE = 32
EPOCHS = 50

# LEARNING_RATE = 2e-5
LEARNING_RATE = 1e-3


LOSS = tf.keras.losses.SparseCategoricalCrossentropy()
METRICS = ['accuracy']

# Random Seed
random_seed = 42 # set random seed for reproducibility
tf.random.set_seed(random_seed) # set random seed for TensorFlow
np.random.seed(random_seed) # set random seed for NumPy

# %% [markdown]
# ## Data Loading

# %%
# Collect the class names
class_names = sorted(os.listdir(train_dir))
n_classes = len(class_names)

# Show
print(f"Total number of classes in train: {n_classes}")
print(f"Classes: {class_names}")
# Out:
# Total number of classes in train: 20
# Classes: ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# %% [markdown]
# ### Check Corrupt Data

# %%
def load_image(image_path: str) -> tf.Tensor:
    
    '''
    The task of the function is to load the image present in the specified given image path. Loading the image the function also performed some 
    preprocessing steps such as resizing and normalization.
    
    Argument:
        image_path(str) : This is a string which represents the location of the image file to be loaded.
        
    Returns:
        image(tf.Tensor) : This is the image which is loaded from the given image part in the form of a tensor.
    '''
    
    # Check if image path exists
    assert os.path.exists(image_path), f'Invalid image path: {image_path}'
    
    # Read the image file
    image = tf.io.read_file(image_path)
    
    # Load the image
    try:
        image = tfi.decode_jpeg(image, channels=3)
    except:
        image = tfi.decode_png(image, channels=3)
    
    # Change the image data type
    image = tfi.convert_image_dtype(image, tf.float32)
    
    # Resize the Image
    image = tfi.resize(image, (IMAGE_SIZE, IMAGE_SIZE))
    
    # Rescale pixel values to be in the range [0, 1]
    image = tf.image.per_image_standardization(image)
    
    # Convert image data type to tf.float32
    image = tf.cast(image, tf.float32)
    
    return image

# %%
def load_dataset(root_path: str, class_names: list, batch_size: int = 32, buffer_size: int = 1000) -> Tuple[np.ndarray, np.ndarray]:
    '''
    Load and preprocess images from the given root path and return them as numpy arrays.

    Args:
        root_path (str): Path to the root directory where all the subdirectories (class names) are present.
        class_names (list): List of the names of all the subdirectories (class names).
        batch_size (int): Batch size of the final dataset. Defaults to 32.
        buffer_size (int): Buffer size to use when shuffling the data. Defaults to 1000.

    Returns:
        Two numpy arrays, one containing the images and the other containing their respective labels.
    '''

    # Collect total number of data samples
    n_samples = sum([len(os.listdir(os.path.join(root_path, name))) for name in class_names])

    # Create arrays to store images and labels
    images = np.empty(shape=(n_samples, IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
    labels = np.empty(shape=(n_samples, 1), dtype=np.int32)

    errors = []
    
    # Loop over all the image file paths, load and store the images with respective labels
    n_image = 0
    for class_name in tqdm(class_names, desc="Loading"):
        class_path = os.path.join(root_path, class_name)
        for file_path in glob(os.path.join(class_path, "*")):
            # Load the image
            try:
                image = load_image(file_path)
                
                # Assign label
                label = class_names.index(class_name)

                # Store the image and the respective label
                images[n_image] = image
                labels[n_image] = label

                # Increment the number of images processed
                n_image += 1
                
            except:
                errors.append(file_path)
            
    # Shuffle the data
    indices = np.random.permutation(n_samples)
    images = images[indices]
    labels = labels[indices]
    
    print('num of errors:', len(errors))

    return images, labels, errors

# %% [markdown]
# ### to check corrupt data

# %%
# # Load the training dataset
# X_train, y_train, err_train = load_dataset(root_path = train_dir, class_names = class_names)

# # # Load the validation dataset
# X_valid, y_valid, err_val = load_dataset(root_path = val_dir, class_names = class_names)

# # Load the testing dataset
# X_test, y_test, err_test = load_dataset(root_path = test_dir, class_names = class_names)

# %%
# print('train err:', err_train)
# print('val err:', err_val)
# print('test err:', err_test)

# %%
# del X_train, y_train, X_valid, y_valid, X_test, y_test

# %% [markdown]
# ### Drop corrupted data

# %%
corrupted = '/kaggle/working/dataset/clean_data_splitted_convert/train/ra/000021.jpg'
os.remove(corrupted)

# %% [markdown]
# ### Augmentasi

# %%
pass

# %% [markdown]
# ### Input Preprocessing Pipeline
#
# - Rescaling
# - Standardization

# %%
def load_and_preprocess_image(image, label):
    # Resize the image to the desired size
    image = tf.image.resize(image, [IMAGE_SIZE, IMAGE_SIZE])
    
    # Rescale pixel values to be in the range [0, 1]
    image = tf.image.per_image_standardization(image)
    
#     # Convert image data type to tf.float32
#     image = tf.cast(image, tf.float32)
    
    return image, label

# %% [markdown]
# ### Load with Tensor Datasets

# %%
# del train_ds, val_ds, test_ds
# del train_ds_mapped, val_ds_mapped, test_ds_mapped

# Create a dataset from the data directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(train_dir, 
#                                                                labels='inferred', 
#                                                                label_mode='int',
#                                                                image_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                               batch_size=BATCH_SIZE
                                                              )

val_ds = tf.keras.preprocessing.image_dataset_from_directory(val_dir,
#                                                              labels='inferred', 
#                                                              label_mode='int',
#                                                              image_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                             batch_size=BATCH_SIZE
                                                              )

test_ds = tf.keras.preprocessing.image_dataset_from_directory(test_dir, 
#                                                               labels='inferred', 
#                                                               label_mode='int',
#                                                               image_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                              batch_size=BATCH_SIZE
                                                              )
# Out:
# Found 3404 files belonging to 20 classes.
# Found 207 files belonging to 20 classes.
# Found 202 files belonging to 20 classes.

# %% [markdown]
# ### preprocessing

# %%
train_ds_mapped = train_ds.map(load_and_preprocess_image)
val_ds_mapped = val_ds.map(load_and_preprocess_image)
test_ds_mapped = test_ds.map(load_and_preprocess_image)

# %% [markdown]
# ### Data Distribution

# %%
# Calculate class distribution
class_dis = [len(os.listdir(train_dir + name)) for name in class_names]
# class_dis = [len(os.listdir(val_dir + name)) for name in class_names]
# class_dis = [len(os.listdir(test_dir + name)) for name in class_names]

# Visualize using interactive pie chart
pie_chart = px.pie(values=class_dis, names=class_names, color=class_names)
pie_chart.update_layout({'title':{'text':"Class Distribution"}})
pie_chart.show()

# Visualize using interactive bar chart
bar_chart = px.bar(y=class_dis, x=class_names, color=class_names)
bar_chart.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="57d7185a-6518-4150-80da-03099bee3092" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57d7185a-6518-4150-80da-03099bee3092")) {                    Plotly.newPlot(                        "57d7185a-6518-4150-80da-03099bee3092",                        [{"customdata":[["ba"],["ca"],["da"],["dha"],["ga"],["ha"],["ja"],["ka"],["la"],["ma"],["na"],["nga"],["nya"],["pa"],["ra"],["sa"],["ta"],["tha"],["wa"],["ya"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["ba","ca","da","dha","ga","ha","ja","ka","la","ma","na","nga","nya","pa","ra","sa","ta","tha","wa","ya"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"","showlegend":true,"values":[172,182,167,144,159,164,176,162,169,172,176,178,169,187,157,185,155,180,162,188],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...
# <div>                            <div id="9b0a7bad-d52e-43ec-a068-2245464aa368" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b0a7bad-d52e-43ec-a068-2245464aa368")) {                    Plotly.newPlot(                        "9b0a7bad-d52e-43ec-a068-2245464aa368",                        [{"alignmentgroup":"True","hovertemplate":"color=ba<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ba","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ba","offsetgroup":"ba","orientation":"v","showlegend":true,"textposition":"auto","x":["ba"],"xaxis":"x","y":[172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ca<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ca","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ca","offsetgroup":"ca","orientation":"v","showlegend":true,"textposition":"auto","x":["ca"],"xaxis":"x","y":[182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=da<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"da","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"da","offsetgroup":"da","orientation":"v","showlegend":true,"textposition":"auto","x":["da"],"xaxis":"x","y":[167],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=dha<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"dha","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dha","offsetgroup":"dha","orientation":"v","showlegend":true,"textposition":"auto","x":["dha"],"xaxis":"x","y":[144],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ga<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ga","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ga","offsetgroup":"ga","orientation":"v","showlegend":true,"textposition":"auto","x":["ga"],"xaxis":"x","y":[159],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ha<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ha","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ha","offsetgroup":"ha","orientation":"v","showlegend":true,"textposition":"auto","x":["ha"],"xaxis":"x","y":[164],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ja<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ja","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"ja","offsetgroup":"ja","orientation":"v","showlegend":true,"textposition":"auto","x":["ja"],"xaxis":"x","y":[176],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ka<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ka","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"ka","offsetgroup":"ka","orientation":"v","showlegend":true,"textposition":"auto","x":["ka"],"xaxis":"x","y":[162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=la<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"la","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"la","offsetgroup":"la","orientation":"v","showlegend":true,"textposition":"auto","x":["la"],"xaxis":"x","y":[169],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ma<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"ma","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"ma","offsetgroup":"ma","orientation":"v","showlegend":true,"textposition":"auto","x":["ma"],"xaxis":"x","y":[172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=na<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"na","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"na","offsetgroup":"na","orientation":"v","showlegend":true,"textposition":"auto","x":["na"],"xaxis":"x","y":[176],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=nga<br>x=%{x}<br>y=%{y}<extra></extra>","legendgro ...

# %% [markdown]
# ### Data Visualization

# %%
def plot_images(dataset: tf.data.Dataset, n_rows: int = 5, n_cols: int = 4, class_names=class_names, figsize=(20, 20), model=None, check=False):
    """
    Plots a grid of images and their corresponding labels from a tf.data.Dataset object.

    Args:
        dataset (tf.data.Dataset): A TensorFlow dataset object containing the images and labels to plot.
        n_rows (int): Number of rows in the plot grid. Default is 1.
        n_cols (int): Number of columns in the plot grid. Default is 4.
        class_names (list): A list of strings mapping the integer labels to their corresponding class names. Default is None.
        figsize (tuple): A tuple specifying the size of the figure. Default is (10, 10).
    """
    
    for images, labels in dataset.take(1):
#     images, labels = next(iter(dataset))
    
        # Create a figure to display the images
        fig = plt.figure(figsize=figsize)

        # Loop over the number of rows and columns
        for i in range(n_rows * n_cols):

            label = int(labels[i].numpy())
            title = "true: "+class_names[label]

            if model:
                pred = model.predict(images[i][np.newaxis])

                if check:
                    if label == np.argmax(pred):
                        continue

                pred_label = f"Pred: {np.argmax(pred)}"
                pred_percentage = f" ({np.max(pred) * 100:.2f}%)"
                if class_names:
                    pred_label += f" ({class_names[np.argmax(pred)]})"
                title += f"\n{pred_label} {pred_percentage}"

            # Create a subplot for each image
            ax = fig.add_subplot(n_rows, n_cols, i+1)    

            # Plot the image
            ax.imshow(images[i].numpy().astype("uint8"))

            # Set the title to the corresponding label
            ax.set_title(title)

            # Remove the axis ticks
            ax.set_xticks([])
            ax.set_yticks([])
    
    # Show the plot
    plt.show()

# %%
plot_images(train_ds)

# %%
plot_images(train_ds_mapped)

# %% [markdown]
# ## Train and Fine Tuning

# %%
def timer(start_time: datetime = None) -> "typing.Union[datetime.datetime, str]":
    """
    Measures the time elapsed from a given start time.

    If no start time is provided, returns the current time. If a start time is provided, returns a formatted string
    representing the time elapsed from the start time to the current time.

    Args:
        start_time (datetime.datetime, optional): The start time to measure elapsed time from, or None to get the current time. Defaults to None.

    Returns:
        Union[datetime.datetime, str]: The current time if no start time is provided, or a formatted string representing the elapsed time.
    """
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        return "%i hours %i minutes and %s seconds." % (
            thour,
            tmin,
            round(tsec, 2),
        )

# %%
def plot_history(history):
    # Collect the history of the training run
    history_plot = pd.DataFrame(history.history)
    
    # Create a figure to display the model's performance
    plt.figure(figsize=(20, 5))

    # Plot the loss curve in the first subplot
    plt.subplot(1, 2, 1)
    plt.title("Inception - Loss Curve")
    plt.plot(history_plot['loss'], label="Training Loss")
    plt.plot(history_plot['val_loss'], label="Validation Loss")

    # Horizontal line to show the testing performance
    plt.axhline(y=test_loss, label="Test Loss", linestyle='--', color='green')

    # Set the x- and y-labels, and the x- and y-limits
    plt.xlabel("Epochs")
    plt.ylabel("Cross Entropy Loss")
    # plt.ylim([0, 0.4])

    # Show the legend and grid
    plt.legend()
    plt.grid()

    # Plot the accuracy curve in the second subplot
    plt.subplot(1, 2, 2)
    plt.title("Inception - Accuracy Curve")
    plt.plot(history_plot['accuracy'], label="Training Accuracy")
    plt.plot(history_plot['val_accuracy'], label="Validation Accuracy")

    # Horizontal line to show the testing performance
    plt.axhline(y=test_acc, label="Test Accuracy", linestyle='--', color='green')

    # Set the x- and y-labels, and the x- and y-limits
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    # plt.ylim([0.85, 1])

    # Show the legend and grid
    plt.legend()
    plt.grid()

    # Display the plot
    plt.show()

# %% [markdown]
# ### Full Freeze

# %%
# Inception

inception = InceptionV3(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)

inception.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
name = 'aksara_jawa_inception_full_freeze_v1'

inception_transferred_full = Sequential([
    inception,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(n_classes, activation='softmax')
], name=name)

inception_transferred_full.compile(
    loss=LOSS,
    optimizer=Adam(learning_rate=LEARNING_RATE),
    metrics=METRICS
)

inception_transferred_full.summary()
# Out:
# Model: "aksara_jawa_inception_full_freeze_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 20)                40980
#
# =================================================================
# Total params: 21,843,764
# Trainable params: 40,980
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# Print the trainable status of each layer
for layer in inception_transferred_full.layers:
    print(f'{layer.name}: {layer.trainable}')
# Out:
# inception_v3: False
# global_average_pooling2d: True
# dropout: True
# dense: True

# %%
print(f"\nTraining {name} Model: ")

# steps_per_epoch = len(X_train)
# STEPS_PER_EPOCH = 50

time = timer(None)
history_full = inception_transferred_full.fit(
    train_ds_mapped, 
    validation_data=val_ds_mapped, 
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(f"checkpoint-{name}.h5", save_best_only=True)
    ],
    batch_size=BATCH_SIZE,
#     steps_per_epoch=STEPS_PER_EPOCH
)
time_taken = timer(time)
print(time_taken)
# Out:
# Training aksara_jawa_inception_full_freeze_v1 Model:
# Epoch 1/50
# 107/107 [==============================] - 29s 159ms/step - loss: 3.0340 - accuracy: 0.1096 - val_loss: 2.6674 - val_accuracy: 0.2222
# Epoch 2/50
# 107/107 [==============================] - 14s 132ms/step - loss: 2.6637 - accuracy: 0.2106 - val_loss: 2.3974 - val_accuracy: 0.2609
# Epoch 3/50
# 107/107 [==============================] - 14s 128ms/step - loss: 2.4072 - accuracy: 0.2844 - val_loss: 2.2051 - val_accuracy: 0.3816
# Epoch 4/50
# 107/107 [==============================] - 14s 129ms/step - loss: 2.2551 - accuracy: 0.3414 - val_loss: 2.0518 - val_accuracy: 0.4493
# Epoch 5/50
# 107/107 [==============================] - 14s 126ms/step - loss: 2.1223 - accuracy: 0.3848 - val_loss: 1.9662 - val_accuracy: 0.4589
# Epoch 6/50
# 107/107 [==============================] - 14s 124ms/step - loss: 2.0245 - accuracy: 0.4039 - val_loss: 1.8683 - val_accuracy: 0.5072
# Epoch 7/50
# 107/107 [==============================] - 14s 125ms/step - loss: 1.9145 - accuracy: 0.4465 - val_loss: 1.8245 - val_accuracy: 0.4783
# Epoch 8/50
# 107/107 [==============================] - 14s 126ms/step - loss: 1.8706 - accuracy: 0.4627 - val_loss: 1.7502 - val_accuracy: 0.5459
# Epoch 9/50
# 107/107 [==============================] - 14s 133ms/step - loss: 1.8354 - accuracy: 0.4709 - val_loss: 1.6869 - val_accuracy: 0.5362
# Epoch 10/50
# 107/107 [==============================] - 14s 124ms/step - loss: 1.7795 - accuracy: 0.4932 - val_loss: 1.6310 - val_accuracy: 0.5942
# Epoch 11/50
# 107/107 [==============================] - 14s 131ms/step - loss: 1.7178 - accuracy: 0.5079 - val_loss: 1.6081 - val_accuracy: 0.5749
# Epoch 12/50
# 107/107 [==============================] - 13s 120ms/step - loss: 1.6981 - accuracy: 0.5000 - val_loss: 1.5935 - val_accuracy: 0.5604
# Epoch 13/50
# 107/107 [==============================] - 14s 131ms/step - loss: 1.6790 - accuracy: 0.5150 - val_loss: 1.5654 - val_accuracy: 0.5556
# Epoch 14/50
# 107/107 [==============================] - 14s 124ms/step - loss: 1.6127 - accuracy: 0.5350 - val_loss: 1.5206 - val_accuracy: 0.5604
# Epoch 15/50
# 107/107 [==============================] - 15s 133ms/step - loss: 1.6001 - accuracy: 0.5447 - val_loss: 1.4924 - val_accuracy: 0.5797
# Epoch 16/50
# 107/107 [==============================] - 13s 120ms/step - loss: 1.5808 - accuracy: 0.5444 - val_loss: 1.4407 - val_accuracy: 0.5894
# Epoch 17/50
# 107/107 [==============================] - 14s 124ms/step - loss: 1.5437 - accuracy: 0.5508 - val_loss: 1.4115 - val_accuracy: 0.6232
# Epoch 18/50
# 107/107 [==============================] - 14s 126ms/step - loss: 1.5315 - accuracy: 0.5617 - val_loss: 1.4019 - val_accuracy: 0.6232
# Epoch 19/50
# 107/107 [==============================] - 13s 117ms/step - loss: 1.5015 - accuracy: 0.5617 - val_loss: 1.4445 - val_accuracy: 0.5942
# Epoch 20/50
# 107/107 [==============================] - 13s 123ms/step - loss: 1.4709 - accuracy: 0.5743 - val_loss: 1.3762 - val_accuracy: 0.6135
# Epoch 21/50
# 107/107 [==============================] - 13s 123ms/step - loss: 1.5021 - accuracy: 0.5505 - val_loss: 1.3627 - val_accuracy: 0.6135
# Epoch 22/50
# 107/107 [==============================] - 14s 125ms/step - loss: 1.4686 - accuracy: 0.5729 - val_loss: 1.3541 - val_accuracy: 0.6329
# Epoch 23/50
# 107/107 [==============================] - 13s 122ms/step - loss: 1.4418 - accuracy: 0.5790 - val_loss: 1.3123 - val_accuracy: 0.6570
# Epoch 24/50
# 107/107 [==============================] - 14s 126ms/step - loss: 1.4264 - accuracy: 0.5828 - val_loss: 1.2915 - val_accuracy: 0.6570
# Epoch 25/50
# 107/107 [==============================] - 13s 121ms/step - loss: 1.4133 - accuracy: 0.5975 - val_loss: 1.2888 - val_accuracy: 0.6425
# Epoch 26/50
# 107/107 [==============================] - 13s 121ms/step - loss: 1.3989 - accuracy: 0.5884 - val_loss: 1.2976 - val_accuracy: 0.6473
# Epoch 27/50
# 107/107 [==============================] - 13s 119ms/step - loss: 1.3909 - accuracy: 0.5946 - val_loss: 1.2944 - val_accuracy: 0.6473
# Epoch 28/50
# 107/107 [==============================] - 14s 124ms/step - loss: 1.3798 - accuracy: 0.5934 - val_loss: 1.2571 - val_accuracy: 0.6329
# Epoch 29/50
# 107/107 [==============================] - 13s 119ms/step - loss: 1.3930 - accuracy: 0.5849 - val_loss: 1.2973 - val_accuracy: 0.6329
# Epoch 30/50
# 107/107 [==============================] - 14s 132ms/step - loss: 1.4100 - accuracy: 0.5814 - val_loss: 1.2433 - val_accuracy: 0.6618
# Epoch 31/50
# 107/107 [==============================] - 14s 127ms/step - loss: 1.3602 - accuracy: 0.5984 - val_loss: 1.2112 - val_accuracy: 0.6667
# Epoch 32/50
# 107/107 [==============================] - 14s 130ms/step - loss: 1.3617 - accuracy: 0.5893 - val_loss: 1.2020 - val_accuracy: 0.6570
# Epoch 33/50
# 107/107 [==============================] - 14s 124ms/step - loss: 1.3517 - accuracy: 0.6040 - val_loss: 1.1997 - val_accuracy: 0.6860
# Epoch 34/50
# 107/107 [==============================] - 14s 126ms/step - loss: 1.3575 - accuracy: 0.5993 - val_loss: 1.1936 - val_accuracy: 0.6522
# Epoch 35/50
# 107/107 [==============================] - 13s 116ms/step - loss: 1.3057 - accuracy: 0.6193 - val_loss: 1.2683 - val_accuracy: 0.6377
# Epoch 36/50
# 107/107 [==============================] - 13s 118ms/step - loss: 1.3033 - accuracy: 0.6131 - val_loss: 1.2107 - val_accuracy: 0.6908
# Epoch 37/50
# 107/107 [==============================] - 13s 120ms/step - loss: 1.3020 - accuracy: 0.6184 - val_loss: 1.1876 - val_accuracy: 0.6763
# Epoch 38/50
# 107/107 [==============================] - 14s 127ms/step - loss: 1.3187 - accuracy: 0.6157 - val_loss: 1.1887 - val_accuracy: 0.6908
# Epoch 39/50
# 107/107 [==============================] - 13s 116ms/step - loss: 1.2886 - accuracy: 0.6207 - val_loss: 1.2004 - val_accuracy: 0.6715
# Epoch 40/50
# 107/107 [==============================] - 12s 113ms/step - loss: 1.3071 - accuracy: 0.6093 - val_loss: 1.1955 - val_accuracy: 0.6812
# 0 hours 10 minutes and 29.6 seconds.

# %%
test_loss, test_acc = inception_transferred_full.evaluate(test_ds_mapped)
print("Loss    : {:.4}".format(test_loss))
print("Accuracy: {:.4}%".format(test_acc*100))
# Out:
# 7/7 [==============================] - 2s 217ms/step - loss: 1.3216 - accuracy: 0.6634
# Loss    : 1.322
# Accuracy: 66.34%

# %%
plot_history(history_full)

# %%
plot_images(test_ds_mapped, model=inception_transferred_full, n_rows=5)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
inception_transferred_full.save(name+'.h5')

# %% [markdown]
# ### Half Freeze

# %%
# Inception

inception = InceptionV3(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)

inception.trainable = True

# %%
num_layers = len(inception.layers) // 2
num_layers

for i in range(num_layers):
    inception.layers[i].trainable = False

# %%
name = 'aksara_jawa_inception_half_freeze_v1'

inception_transferred_half = Sequential([
    inception,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(n_classes, activation='softmax')
], name=name)

inception_transferred_half.compile(
    loss=LOSS,
    optimizer=Adam(learning_rate=LEARNING_RATE),
    metrics=METRICS
)

inception_transferred_half.summary()
# Out:
# Model: "aksara_jawa_inception_half_freeze_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 20)                40980
#
# =================================================================
# Total params: 21,843,764
# Trainable params: 16,830,420
# Non-trainable params: 5,013,344
# _________________________________________________________________

# %%
# Print the trainable status of each layer
for layer in inception_transferred_half.layers:
    print(f'{layer.name}: {layer.trainable}')
# Out:
# inception_v3: True
# global_average_pooling2d_1: True
# dropout_1: True
# dense_1: True

# %%
# plot_model(
#     inception_transferred,
#     to_file='inception_transferred.png',
#     show_shapes=True,
#     show_dtype=True,
#     show_layer_names=True,
#     rankdir='TB',
#     expand_nested=False,
# #     expand_nested=True,
#     dpi=96,
#     show_layer_activations=True
# )

# %%
print(f"\nTraining {name} Model: ")

# steps_per_epoch = len(X_train)
# STEPS_PER_EPOCH = 50

time = timer(None)
history_half = inception_transferred_half.fit(
    train_ds_mapped, 
    validation_data=val_ds_mapped, 
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(f"checkpoint-{name}.h5", save_best_only=True)
    ],
    batch_size=BATCH_SIZE,
#     steps_per_epoch=STEPS_PER_EPOCH
)
time_taken = timer(time)
print(time_taken)
# Out:
# Training aksara_jawa_inception_half_freeze_v1 Model:
# Epoch 1/50
# 107/107 [==============================] - 42s 185ms/step - loss: 0.7522 - accuracy: 0.7709 - val_loss: 5.3568 - val_accuracy: 0.4589
# Epoch 2/50
# 107/107 [==============================] - 18s 164ms/step - loss: 0.1991 - accuracy: 0.9430 - val_loss: 0.6176 - val_accuracy: 0.8841
# Epoch 3/50
# 107/107 [==============================] - 19s 172ms/step - loss: 0.0916 - accuracy: 0.9736 - val_loss: 0.0270 - val_accuracy: 0.9855
# Epoch 4/50
# 107/107 [==============================] - 17s 158ms/step - loss: 0.0944 - accuracy: 0.9712 - val_loss: 0.7661 - val_accuracy: 0.8454
# Epoch 5/50
# 107/107 [==============================] - 18s 161ms/step - loss: 0.0746 - accuracy: 0.9827 - val_loss: 0.1775 - val_accuracy: 0.9420
# Epoch 6/50
# 107/107 [==============================] - 18s 161ms/step - loss: 0.0652 - accuracy: 0.9818 - val_loss: 0.1199 - val_accuracy: 0.9758
# 0 hours 2 minutes and 14.77 seconds.

# %%
test_loss, test_acc = inception_transferred_half.evaluate(test_ds_mapped)
print("Loss    : {:.4}".format(test_loss))
print("Accuracy: {:.4}%".format(test_acc*100))
# Out:
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0750 - accuracy: 0.9703
# Loss    : 0.07495
# Accuracy: 97.03%

# %%
plot_history(history_half)

# %%
plot_images(test_ds_mapped, model=inception_transferred_half, n_rows=5)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
inception_transferred_half.save(name+'.h5')

# %% [markdown]
# ### No Freeze

# %%
# Inception

inception = InceptionV3(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)

inception.trainable = True

# %%
name = 'aksara_jawa_inception_no_freeze_v1'

inception_transferred_no = Sequential([
    inception,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(n_classes, activation='softmax')
], name=name)

inception_transferred_no.compile(
    loss=LOSS,
    optimizer=Adam(learning_rate=LEARNING_RATE),
    metrics=METRICS
)

inception_transferred_no.summary()
# Out:
# Model: "aksara_jawa_inception_no_freeze_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 20)                40980
#
# =================================================================
# Total params: 21,843,764
# Trainable params: 21,809,332
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
# Print the trainable status of each layer
for layer in inception_transferred_no.layers:
    print(f'{layer.name}: {layer.trainable}')
# Out:
# inception_v3: True
# global_average_pooling2d_2: True
# dropout_2: True
# dense_2: True

# %%
print(f"\nTraining {name} Model: ")

# steps_per_epoch = len(X_train)
# STEPS_PER_EPOCH = 50

time = timer(None)
history_no = inception_transferred_no.fit(
    train_ds_mapped, 
    validation_data=val_ds_mapped, 
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(f"checkpoint-{name}.h5", save_best_only=True)
    ],
    batch_size=BATCH_SIZE,
#     steps_per_epoch=STEPS_PER_EPOCH
)
time_taken = timer(time)
print(time_taken)
# Out:
# Training aksara_jawa_inception_no_freeze_v1 Model:
# Epoch 1/50
# 107/107 [==============================] - 70s 303ms/step - loss: 0.6972 - accuracy: 0.7926 - val_loss: 37.6595 - val_accuracy: 0.0918
# Epoch 2/50
# 107/107 [==============================] - 30s 274ms/step - loss: 0.1794 - accuracy: 0.9480 - val_loss: 1.9604 - val_accuracy: 0.6860
# Epoch 3/50
# 107/107 [==============================] - 30s 275ms/step - loss: 0.1056 - accuracy: 0.9706 - val_loss: 0.3551 - val_accuracy: 0.8986
# Epoch 4/50
# 107/107 [==============================] - 30s 279ms/step - loss: 0.0802 - accuracy: 0.9777 - val_loss: 0.0741 - val_accuracy: 0.9807
# Epoch 5/50
# 107/107 [==============================] - 29s 263ms/step - loss: 0.0474 - accuracy: 0.9882 - val_loss: 0.1990 - val_accuracy: 0.9517
# Epoch 6/50
# 107/107 [==============================] - 30s 279ms/step - loss: 0.0372 - accuracy: 0.9903 - val_loss: 0.0736 - val_accuracy: 0.9758
# Epoch 7/50
# 107/107 [==============================] - 29s 269ms/step - loss: 0.0705 - accuracy: 0.9818 - val_loss: 0.1202 - val_accuracy: 0.9710
# Epoch 8/50
# 107/107 [==============================] - 29s 266ms/step - loss: 0.0541 - accuracy: 0.9847 - val_loss: 0.1137 - val_accuracy: 0.9758
# Epoch 9/50
# 107/107 [==============================] - 30s 277ms/step - loss: 0.0273 - accuracy: 0.9924 - val_loss: 0.0429 - val_accuracy: 0.9903
# Epoch 10/50
# 107/107 [==============================] - 28s 263ms/step - loss: 0.0468 - accuracy: 0.9868 - val_loss: 0.1826 - val_accuracy: 0.9372
# Epoch 11/50
# 107/107 [==============================] - 29s 263ms/step - loss: 0.0421 - accuracy: 0.9880 - val_loss: 0.3875 - val_accuracy: 0.9275
# Epoch 12/50
# 107/107 [==============================] - 29s 270ms/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 0.0690 - val_accuracy: 0.9710
# 0 hours 7 minutes and 8.68 seconds.

# %%
test_loss, test_acc = inception_transferred_no.evaluate(test_ds_mapped)
print("Loss    : {:.4}".format(test_loss))
print("Accuracy: {:.4}%".format(test_acc*100))
# Out:
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0302 - accuracy: 0.9950
# Loss    : 0.03019
# Accuracy: 99.5%

# %%
plot_history(history_no)

# %%
plot_images(test_ds_mapped, model=inception_transferred_no, n_rows=5)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
inception_transferred_no.save(name+'.h5')
